# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharv21sawant/data_visualization/blob/main/7/12/23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# summarize the data with the statistic
import pandas as pd
df=pd.DataFrame({"marks":[51,45,45,48,88],"roll no ":[20,30,40,50,60],"name":['atharv','vivek','pradeep','ritesh','vinayak'],"class":['A','A','B','B','B']})
print(df)
# Out:
#    marks  roll no      name class
# 0     51        20   atharv     A
# 1     45        30    vivek     A
# 2     45        40  pradeep     B
# 3     48        50   ritesh     B
# 4     88        60  vinayak     B

# %%
df.isnull()
# Out:
#    marks  roll no    name
# 0  False     False  False
# 1  False     False  False
# 2  False     False  False
# 3  False     False  False
# 4  False     False  False

# %%
df.sum()
# Out:
# marks                                   277
# roll no                                 200
# name        atharvvivekpradeepriteshvinayak
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   marks     5 non-null      int64
#  1   roll no   5 non-null      int64
#  2   name      5 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes

# %%
df.mean()
# Out:
# <ipython-input-5-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# marks       55.4
# roll no     40.0
# dtype: float64

# %%
df.describe()
# Out:
#            marks   roll no
# count   5.000000   5.000000
# mean   55.400000  40.000000
# std    18.392933  15.811388
# min    45.000000  20.000000
# 25%    45.000000  30.000000
# 50%    48.000000  40.000000
# 75%    51.000000  50.000000
# max    88.000000  60.000000

# %%
df.describe(include="object")
# Out:
#           name
# count        5
# unique       5
# top     atharv
# freq         1
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('index').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
df.nunique()
# Out:
# marks       4
# roll no     5
# name        5
# class       2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["name"]
# Out:
# 0     atharv
# 1      vivek
# 2    pradeep
# 3     ritesh
# 4    vinayak
# Name: name, dtype: object

# %%
df["marks"].duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: marks, dtype: bool

# %%
df["marks"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0    51
# 1    45
# 2    45
# 3    48
# 4    88
# Name: marks, dtype: int64>

# %%
df.value_counts()
# Out:
# marks  roll no   name     class
# 45     30        vivek    A        1
#        40        pradeep  B        1
# 48     50        ritesh   B        1
# 51     20        atharv   A        1
# 88     60        vinayak  B        1
# dtype: int64

# %%
df['marks'].mean()
# Out:
# 55.4

# %%
df['marks'].var()
# Out:
# 338.29999999999995

# %%
a=df.corr()
print(a)
# Out:
#              marks  roll no
# marks     1.000000  0.661926
# roll no   0.661926  1.000000
# <ipython-input-33-254674a1c818>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a=df.corr()

# %%
import seaborn as sns
sns.heatmap(a,annot=True,fmt='.1f',cmap='plasma')
# Out:
# <Axes: >
